# %% [markdown]
# # Import Req Lib

# %%
# %matplotlib inline


import shutil
import random
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

from tensorflow.keras import layers,regularizers, optimizers
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LeakyReLU,Dense, Activation, Flatten, Dropout, BatchNormalization,Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

import os
import time

from matplotlib import figure

# %% [markdown]
# # Define 4 worker

# %%
# Set the number of threads
os.environ['OMP_NUM_THREADS'] = '4'  # OpenMP threads for parallelism
os.environ['TF_NUM_INTEROP_THREADS'] = '4'  # Threads for inter-operation parallelism
os.environ['TF_NUM_INTRAOP_THREADS'] = '4'  # Threads for intra-operation parallelism

# Confirm TensorFlow is using the specified number of threads
tf.config.threading.set_inter_op_parallelism_threads(4)
tf.config.threading.set_intra_op_parallelism_threads(4)

# %% [markdown]
# # Train Val data Split

# %%
source_dir = r"Convert_Audio_File_to_jpg_file\genres"
target_dir = r'genres_train_val_split_data'
split_ratio = 0.8

def Train_Test_Split(source_dir,target_dir,split_ratio):
    # Define source and target directories
    train_dir = os.path.join(target_dir, 'train')
    val_dir = os.path.join(target_dir, 'val')
    
    # Create target directories if they don't exist
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    
    # Get the list of class directories
    classes = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
        
    for class_name in classes:
        # Create class directories in train and val folders
        os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
        os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)
        
        # Get list of images in the class directory
        class_dir = os.path.join(source_dir, class_name)
        images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
        
        # Shuffle the images
        random.shuffle(images)
        
        # Compute the split point
        split_point = int(len(images) * split_ratio)
        
        # Split the images into training and validation sets
        train_images = images[:split_point]
        val_images = images[split_point:]
        
        # Move the images to the respective directories
        for img in train_images:
            shutil.copy(os.path.join(class_dir, img), os.path.join(train_dir, class_name, img))
        
        for img in val_images:
            shutil.copy(os.path.join(class_dir, img), os.path.join(val_dir, class_name, img))
    
    print("Data split completed successfully!")

# %%
Train_Test_Split(source_dir,target_dir,split_ratio)
# Out:
# Data split completed successfully!

# %% [markdown]
# # Load the Data

# %%
WIDTH = 64
HEIGHT = 64
BATCH_SIZE = 32
TRAIN_DIR=r'genres_train_val_split_data/train'
val_dir = r'genres_train_val_split_data/val'

# data prep
train_datagen = ImageDataGenerator(
    rescale=1./255.,validation_split=0.25)


train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(HEIGHT, WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical')

validation_gen = train_datagen.flow_from_directory(
    val_dir,target_size = (HEIGHT,WIDTH),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical'
 )
# Out:
# Found 800 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %% [markdown]
# # Model Architecture

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=(64,64,3)))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.compile(optimizers.RMSprop(learning_rate=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 62, 62, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 31, 31, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 29, 29, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 29, 29, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 12, 12, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,679,626 (10.22 MB)
#  Trainable params: 2,679,626 (10.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# Measure the execution time
start_time = time.time()

model.fit(train_generator,validation_data=validation_gen,epochs=200)

end_time = time.time()
elapsed_time = end_time - start_time
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - accuracy: 0.0988 - loss: 2.3194 - val_accuracy: 0.1100 - val_loss: 2.2993
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.1554 - loss: 2.2660 - val_accuracy: 0.1250 - val_loss: 2.2671
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.1898 - loss: 2.1595 - val_accuracy: 0.2250 - val_loss: 2.0882
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.2153 - loss: 2.0909 - val_accuracy: 0.2550 - val_loss: 1.9880
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.2758 - loss: 2.0226 - val_accuracy: 0.2050 - val_loss: 2.4055
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.2977 - loss: 2.0226 - val_accuracy: 0.2800 - val_loss: 1.9312
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.2820 - loss: 1.9655 - val_accuracy: 0.3250 - val_loss: 1.9396
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.2924 - loss: 1.9134 - val_accuracy: 0.3450 - val_loss: 1.8502
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.2824 - loss: 1.9675 - val_accuracy: 0.3000 - val_loss: 1.8508
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.2961 - loss: 1.9090 - val_accuracy: 0.3500 - val_loss: 1.9009
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.3268 - loss: 1.8708 - val_accuracy: 0.3450 - val_loss: 1.7215
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.3863 - loss: 1.7331 - val_accuracy: 0.4050 - val_loss: 1.6818
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.3509 - loss: 1.7057 - val_accuracy: 0.4100 - val_loss: 1.6312
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.4052 - loss: 1.5862 - val_accuracy: 0.4000 - val_loss: 1.5787
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.4641 - loss: 1.5543 - val_accuracy: 0.4200 - val_loss: 1.6143
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.4209 - loss: 1.5746 - val_accuracy: 0.5150 - val_loss: 1.4402
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.4445 - loss: 1.5272 - val_accuracy: 0.4150 - val_loss: 1.7271
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.4506 - loss: 1.4905 - val_accuracy: 0.4750 - val_loss: 1.4163
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.4992 - loss: 1.4144 - val_accuracy: 0.5300 - val_loss: 1.4330
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.4948 - loss: 1.3706 - val_accuracy: 0.4750 - val_loss: 1.4444
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.4864 - loss: 1.4739 - val_accuracy: 0.4800 - val_loss: 1.4918
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.5170 - loss: 1.3581 - val_accuracy: 0.5200 - val_loss: 1.3771
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.4972 - loss: 1.3415 - val_accuracy: 0.5200 - val_loss: 1.4575
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.5358 - loss: 1.2732 - val_accuracy: 0.4850 - val_loss: 1.3633
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.5550 - loss: 1.1884 - val_accuracy: 0.5150 - val_loss: 1.3235
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.5353 - loss: 1.2526 - val_accuracy: 0.5450 - val_loss: 1.3126
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.5502 - loss: 1.1869 - val_accuracy: 0.5050 - val_loss: 1.3167
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.5853 - loss: 1.1522 - val_accuracy: 0.5600 - val_loss: 1.2942
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.5774 - loss: 1.2227 - val_accuracy: 0.5600 - val_loss: 1.2453
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.6245 - loss: 1.1239 - val_accuracy: 0.5600 - val_loss: 1.2904
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.5643 - loss: 1.1819 - val_accuracy: 0.5900 - val_loss: 1.2873
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.5958 - loss: 1.1489 - val_accuracy: 0.5750 - val_loss: 1.2533
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.6111 - loss: 1.1150 - val_accuracy: 0.5150 - val_loss: 1.3312
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.6372 - loss: 1.0135 - val_accuracy: 0.5600 - val_loss: 1.2357
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.6747 - loss: 0.9163 - val_accuracy: 0.4900 - val_loss: 1.4670
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.6046 - loss: 1.0565 - val_accuracy: 0.5550 - val_loss: 1.2462
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.6691 - loss: 0.9596 - val_accuracy: 0.5950 - val_loss: 1.2021
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.6642 - loss: 0.9108 - val_accuracy: 0.6000 - val_loss: 1.3604
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.6746 - loss: 0.9484 - val_accuracy: 0.5800 - val_loss: 1.2538
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.6824 - loss: 0.9095 - val_accuracy: 0.5550 - val_loss: 1.3820
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.7044 - loss: 0.8788 - val_accuracy: 0.5650 - val_loss: 1.3325
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.6903 - loss: 0.8274 - val_accuracy: 0.5300 - val_loss: 1.7242
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.6594 - loss: 0.9513 - val_accuracy: 0.5750 - val_loss: 1.3635
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.7002 - loss: 0.8399 - val_accuracy: 0.5300 - val_loss: 1.5064
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.7210 - loss: 0.8174 - val_accuracy: 0.5750 - val_loss: 1.3422
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.7144 - loss: 0.7565 - val_accuracy: 0.5200 - val_loss: 1.5709
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.7368 - loss: 0.6892 - val_accuracy: 0.5550 - val_loss: 1.4517
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.7461 - loss: 0.7237 - val_accuracy: 0.5800 - val_loss: 1.3379
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.7792 - loss: 0.6085 - val_accuracy: 0.5600 - val_loss: 1.5535
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.7634 - loss: 0.6514 - val_accuracy: 0.6100 - val_loss: 1.3385
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.7803 - loss: 0.6032 - val_accuracy: 0.6050 - val_loss: 1.3158
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.8072 - loss: 0.5522 - val_accuracy: 0.5800 - val_loss: 1.5005
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.7725 - loss: 0.6091 - val_accuracy: 0.5700 - val_loss: 1.4505
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.7858 - loss: 0.5635 - val_accuracy: 0.5850 - val_loss: 1.5051
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.8046 - loss: 0.5368 - val_accuracy: 0.5950 - val_loss: 1.5182
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.8062 - loss: 0.5194 - val_accuracy: 0.5950 - val_loss: 1.6481
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8144 - loss: 0.5301 - val_accuracy: 0.5800 - val_loss: 1.5361
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.8665 - loss: 0.3915 - val_accuracy: 0.6000 - val_loss: 1.5567
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.8440 - loss: 0.4374 - val_accuracy: 0.5600 - val_loss: 1.4604
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 0.8620 - loss: 0.3848 - val_accuracy: 0.5400 - val_loss: 1.6440
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8803 - loss: 0.3636 - val_accuracy: 0.5550 - val_loss: 1.7282
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.8193 - loss: 0.5360 - val_accuracy: 0.5400 - val_loss: 1.6411
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.8431 - loss: 0.3754 - val_accuracy: 0.6150 - val_loss: 1.4515
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.8786 - loss: 0.3577 - val_accuracy: 0.5450 - val_loss: 1.6722
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.8733 - loss: 0.3425 - val_accuracy: 0.5850 - val_loss: 1.6310
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8955 - loss: 0.2885 - val_accuracy: 0.5650 - val_loss: 1.7256
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8501 - loss: 0.4651 - val_accuracy: 0.6150 - val_loss: 1.6982
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9035 - loss: 0.2529 - val_accuracy: 0.5700 - val_loss: 1.7615
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8917 - loss: 0.2851 - val_accuracy: 0.5950 - val_loss: 1.6953
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9196 - loss: 0.2617 - val_accuracy: 0.6000 - val_loss: 1.8511
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.9124 - loss: 0.2774 - val_accuracy: 0.6050 - val_loss: 1.8030
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.8963 - loss: 0.2955 - val_accuracy: 0.6000 - val_loss: 1.9934
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.9076 - loss: 0.2395 - val_accuracy: 0.5700 - val_loss: 1.8668
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9152 - loss: 0.2332 - val_accuracy: 0.6150 - val_loss: 1.8387
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9240 - loss: 0.2577 - val_accuracy: 0.6050 - val_loss: 1.7584
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9350 - loss: 0.2128 - val_accuracy: 0.6100 - val_loss: 1.6951
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9265 - loss: 0.1954 - val_accuracy: 0.5950 - val_loss: 1.9889
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9245 - loss: 0.2409 - val_accuracy: 0.5900 - val_loss: 2.0491
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9232 - loss: 0.1879 - val_accuracy: 0.5650 - val_loss: 1.8662
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9052 - loss: 0.2694 - val_accuracy: 0.5950 - val_loss: 2.1546
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9120 - loss: 0.2247 - val_accuracy: 0.6000 - val_loss: 2.0460
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9401 - loss: 0.1769 - val_accuracy: 0.5350 - val_loss: 2.8004
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.9160 - loss: 0.3042 - val_accuracy: 0.5850 - val_loss: 2.3060
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.9487 - loss: 0.1873 - val_accuracy: 0.5700 - val_loss: 2.4186
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9315 - loss: 0.1930 - val_accuracy: 0.5800 - val_loss: 2.1034
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9567 - loss: 0.1271 - val_accuracy: 0.5850 - val_loss: 2.3671
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9335 - loss: 0.2066 - val_accuracy: 0.6000 - val_loss: 1.9334
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9568 - loss: 0.1311 - val_accuracy: 0.5950 - val_loss: 2.1496
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9376 - loss: 0.1603 - val_accuracy: 0.5900 - val_loss: 2.2640
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9260 - loss: 0.2082 - val_accuracy: 0.6000 - val_loss: 2.0814
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.9625 - loss: 0.1168 - val_accuracy: 0.6100 - val_loss: 2.1045
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9517 - loss: 0.1559 - val_accuracy: 0.5800 - val_loss: 2.2348
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9570 - loss: 0.1279 - val_accuracy: 0.5900 - val_loss: 2.2074
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9396 - loss: 0.1551 - val_accuracy: 0.5700 - val_loss: 2.4605
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9597 - loss: 0.1133 - val_accuracy: 0.6250 - val_loss: 2.4562
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.9634 - loss: 0.1174 - val_accuracy: 0.5900 - val_loss: 2.4002
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9470 - loss: 0.1623 - val_accuracy: 0.5900 - val_loss: 2.4589
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9572 - loss: 0.1400 - val_accuracy: 0.6050 - val_loss: 2.2878
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9603 - loss: 0.0973 - val_accuracy: 0.5350 - val_loss: 3.0043
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9321 - loss: 0.2112 - val_accuracy: 0.5900 - val_loss: 2.3366
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9672 - loss: 0.0919 - val_accuracy: 0.5900 - val_loss: 2.3957
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9751 - loss: 0.0950 - val_accuracy: 0.5600 - val_loss: 3.1377
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9308 - loss: 0.2014 - val_accuracy: 0.5650 - val_loss: 2.2938
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9688 - loss: 0.0760 - val_accuracy: 0.5950 - val_loss: 2.5749
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9555 - loss: 0.1428 - val_accuracy: 0.5700 - val_loss: 2.8446
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9613 - loss: 0.1063 - val_accuracy: 0.6000 - val_loss: 2.7012
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9680 - loss: 0.1195 - val_accuracy: 0.6100 - val_loss: 2.1894
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9813 - loss: 0.0676 - val_accuracy: 0.5600 - val_loss: 2.8297
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9682 - loss: 0.1108 - val_accuracy: 0.6050 - val_loss: 2.2560
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9600 - loss: 0.0861 - val_accuracy: 0.5500 - val_loss: 2.4807
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.9901 - loss: 0.0331 - val_accuracy: 0.5750 - val_loss: 3.0993
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9599 - loss: 0.0965 - val_accuracy: 0.6000 - val_loss: 2.4828
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9767 - loss: 0.1128 - val_accuracy: 0.5500 - val_loss: 3.0234
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.9778 - loss: 0.1199 - val_accuracy: 0.6200 - val_loss: 2.5069
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9714 - loss: 0.0815 - val_accuracy: 0.5850 - val_loss: 2.4735
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9856 - loss: 0.0495 - val_accuracy: 0.5650 - val_loss: 3.0578
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9581 - loss: 0.1138 - val_accuracy: 0.5650 - val_loss: 2.5474
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.9779 - loss: 0.1060 - val_accuracy: 0.5900 - val_loss: 2.5809
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9508 - loss: 0.1209 - val_accuracy: 0.5550 - val_loss: 2.7862
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9584 - loss: 0.1035 - val_accuracy: 0.5650 - val_loss: 3.4357
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9769 - loss: 0.0609 - val_accuracy: 0.6000 - val_loss: 2.6411
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.9836 - loss: 0.0594 - val_accuracy: 0.5900 - val_loss: 2.9944
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9769 - loss: 0.0708 - val_accuracy: 0.5850 - val_loss: 2.9118
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9619 - loss: 0.1153 - val_accuracy: 0.5850 - val_loss: 2.8300
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9547 - loss: 0.1385 - val_accuracy: 0.6200 - val_loss: 2.3655
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9699 - loss: 0.0909 - val_accuracy: 0.5950 - val_loss: 2.4270
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9871 - loss: 0.0374 - val_accuracy: 0.6050 - val_loss: 2.7249
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9913 - loss: 0.0302 - val_accuracy: 0.5950 - val_loss: 3.2541
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.9540 - loss: 0.1573 - val_accuracy: 0.5850 - val_loss: 3.0418
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9660 - loss: 0.1225 - val_accuracy: 0.5700 - val_loss: 3.4789
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9735 - loss: 0.0697 - val_accuracy: 0.5850 - val_loss: 3.1226
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9522 - loss: 0.1828 - val_accuracy: 0.5400 - val_loss: 3.1800
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9661 - loss: 0.0991 - val_accuracy: 0.6000 - val_loss: 2.7314
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9838 - loss: 0.0432 - val_accuracy: 0.6150 - val_loss: 2.4989
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9770 - loss: 0.0880 - val_accuracy: 0.5450 - val_loss: 3.0125
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9697 - loss: 0.0771 - val_accuracy: 0.5650 - val_loss: 2.8676
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9758 - loss: 0.0773 - val_accuracy: 0.6000 - val_loss: 2.6014
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9838 - loss: 0.0626 - val_accuracy: 0.6000 - val_loss: 2.6925
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9921 - loss: 0.0243 - val_accuracy: 0.5700 - val_loss: 3.1255
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9585 - loss: 0.1758 - val_accuracy: 0.5600 - val_loss: 3.1227
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9755 - loss: 0.0930 - val_accuracy: 0.5800 - val_loss: 2.9209
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9894 - loss: 0.0537 - val_accuracy: 0.5800 - val_loss: 2.8844
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9759 - loss: 0.0589 - val_accuracy: 0.5550 - val_loss: 3.0261
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9737 - loss: 0.0843 - val_accuracy: 0.6000 - val_loss: 2.9720
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9891 - loss: 0.0323 - val_accuracy: 0.6150 - val_loss: 2.7695
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9911 - loss: 0.0267 - val_accuracy: 0.5600 - val_loss: 3.5962
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9708 - loss: 0.1366 - val_accuracy: 0.5900 - val_loss: 2.9768
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9863 - loss: 0.0703 - val_accuracy: 0.5800 - val_loss: 2.8742
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9908 - loss: 0.0337 - val_accuracy: 0.5850 - val_loss: 3.0599
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9848 - loss: 0.0437 - val_accuracy: 0.5850 - val_loss: 2.8439
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.9863 - loss: 0.0532 - val_accuracy: 0.6050 - val_loss: 2.9088
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.9725 - loss: 0.0875 - val_accuracy: 0.5750 - val_loss: 2.7078
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - accuracy: 0.9882 - loss: 0.0350 - val_accuracy: 0.5750 - val_loss: 2.8132
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.9901 - loss: 0.0248 - val_accuracy: 0.6000 - val_loss: 2.9080
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.9852 - loss: 0.0533 - val_accuracy: 0.5800 - val_loss: 3.0533
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.9889 - loss: 0.0539 - val_accuracy: 0.5800 - val_loss: 2.7322
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9858 - loss: 0.0549 - val_accuracy: 0.5750 - val_loss: 2.8172
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - accuracy: 0.9926 - loss: 0.0318 - val_accuracy: 0.5600 - val_loss: 3.2638
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.9855 - loss: 0.0405 - val_accuracy: 0.5550 - val_loss: 3.9342
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.9544 - loss: 0.1393 - val_accuracy: 0.5950 - val_loss: 2.9341
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9808 - loss: 0.0595 - val_accuracy: 0.6000 - val_loss: 2.7973
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.9902 - loss: 0.0335 - val_accuracy: 0.5650 - val_loss: 2.8986
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9939 - loss: 0.0099 - val_accuracy: 0.5750 - val_loss: 3.4812
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9819 - loss: 0.0808 - val_accuracy: 0.5850 - val_loss: 2.8321
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9861 - loss: 0.0317 - val_accuracy: 0.6000 - val_loss: 3.1479
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9828 - loss: 0.0662 - val_accuracy: 0.5800 - val_loss: 3.2989
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9714 - loss: 0.1131 - val_accuracy: 0.5650 - val_loss: 3.3289
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9840 - loss: 0.0506 - val_accuracy: 0.5950 - val_loss: 2.9090
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9731 - loss: 0.0571 - val_accuracy: 0.5900 - val_loss: 3.2995
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9996 - loss: 0.0058 - val_accuracy: 0.6350 - val_loss: 3.4628
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9712 - loss: 0.1063 - val_accuracy: 0.6050 - val_loss: 3.2798
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9937 - loss: 0.0142 - val_accuracy: 0.5900 - val_loss: 3.3277
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9844 - loss: 0.0575 - val_accuracy: 0.5400 - val_loss: 3.9566
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9864 - loss: 0.0437 - val_accuracy: 0.5850 - val_loss: 4.4603
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9553 - loss: 0.1974 - val_accuracy: 0.5550 - val_loss: 3.3459
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.9798 - loss: 0.0481 - val_accuracy: 0.5900 - val_loss: 3.6179
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.9642 - loss: 0.1809 - val_accuracy: 0.6000 - val_loss: 3.1965
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9851 - loss: 0.0576 - val_accuracy: 0.6150 - val_loss: 3.5690
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9946 - loss: 0.0215 - val_accuracy: 0.5900 - val_loss: 3.5993
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9813 - loss: 0.0786 - val_accuracy: 0.5800 - val_loss: 3.6514
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9731 - loss: 0.1108 - val_accuracy: 0.5700 - val_loss: 3.6615
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9705 - loss: 0.0869 - val_accuracy: 0.6100 - val_loss: 3.3819
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9886 - loss: 0.0342 - val_accuracy: 0.5950 - val_loss: 3.0725
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9966 - loss: 0.0174 - val_accuracy: 0.5550 - val_loss: 3.2717
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9756 - loss: 0.0677 - val_accuracy: 0.6000 - val_loss: 3.4396
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9813 - loss: 0.0472 - val_accuracy: 0.5950 - val_loss: 3.7238
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9765 - loss: 0.0711 - val_accuracy: 0.5800 - val_loss: 3.6932
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9818 - loss: 0.0670 - val_accuracy: 0.5600 - val_loss: 3.2876
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9906 - loss: 0.0270 - val_accuracy: 0.5800 - val_loss: 3.3999
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.9829 - loss: 0.0546 - val_accuracy: 0.5600 - val_loss: 3.8210
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9967 - loss: 0.0154 - val_accuracy: 0.5800 - val_loss: 3.6804
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9674 - loss: 0.0994 - val_accuracy: 0.6200 - val_loss: 3.7597
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9706 - loss: 0.0727 - val_accuracy: 0.5800 - val_loss: 3.7501
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.9939 - loss: 0.0156 - val_accuracy: 0.5650 - val_loss: 4.2561
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9904 - loss: 0.0263 - val_accuracy: 0.5800 - val_loss: 3.9555
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.9660 - loss: 0.1443 - val_accuracy: 0.6100 - val_loss: 3.5493
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.9868 - loss: 0.0295 - val_accuracy: 0.5350 - val_loss: 4.6878
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.9783 - loss: 0.0935 - val_accuracy: 0.5650 - val_loss: 4.3397
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9844 - loss: 0.0457 - val_accuracy: 0.5500 - val_loss: 4.3827
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9827 - loss: 0.0918 - val_accuracy: 0.5600 - val_loss: 4.0327

# %%
print(f"Execution time: {elapsed_time:.2f} seconds")
# Out:
# Execution time: 1058.27 seconds
