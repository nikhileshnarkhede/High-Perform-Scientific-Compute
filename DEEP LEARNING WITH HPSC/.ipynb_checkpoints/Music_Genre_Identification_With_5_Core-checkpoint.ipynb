# %% [markdown]
# # Import Req Lib

# %%
# %matplotlib inline


import shutil
import random
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

from tensorflow.keras import layers,regularizers, optimizers
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LeakyReLU,Dense, Activation, Flatten, Dropout, BatchNormalization,Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

import os
import time

from matplotlib import figure

# %% [markdown]
# # Define 5 worker

# %%
# Set the number of threads
os.environ['OMP_NUM_THREADS'] = '5'  # OpenMP threads for parallelism
os.environ['TF_NUM_INTEROP_THREADS'] = '5'  # Threads for inter-operation parallelism
os.environ['TF_NUM_INTRAOP_THREADS'] = '5'  # Threads for intra-operation parallelism

# Confirm TensorFlow is using the specified number of threads
tf.config.threading.set_inter_op_parallelism_threads(5)
tf.config.threading.set_intra_op_parallelism_threads(5)

# %% [markdown]
# # Train Val data Split

# %%
source_dir = r"Convert_Audio_File_to_jpg_file\genres"
target_dir = r'genres_train_val_split_data'
split_ratio = 0.8

def Train_Test_Split(source_dir,target_dir,split_ratio):
    # Define source and target directories
    train_dir = os.path.join(target_dir, 'train')
    val_dir = os.path.join(target_dir, 'val')
    
    # Create target directories if they don't exist
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    
    # Get the list of class directories
    classes = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
        
    for class_name in classes:
        # Create class directories in train and val folders
        os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
        os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)
        
        # Get list of images in the class directory
        class_dir = os.path.join(source_dir, class_name)
        images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
        
        # Shuffle the images
        random.shuffle(images)
        
        # Compute the split point
        split_point = int(len(images) * split_ratio)
        
        # Split the images into training and validation sets
        train_images = images[:split_point]
        val_images = images[split_point:]
        
        # Move the images to the respective directories
        for img in train_images:
            shutil.copy(os.path.join(class_dir, img), os.path.join(train_dir, class_name, img))
        
        for img in val_images:
            shutil.copy(os.path.join(class_dir, img), os.path.join(val_dir, class_name, img))
    
    print("Data split completed successfully!")

# %%
Train_Test_Split(source_dir,target_dir,split_ratio)
# Out:
# Data split completed successfully!

# %% [markdown]
# # Load the Data

# %%
WIDTH = 64
HEIGHT = 64
BATCH_SIZE = 32
TRAIN_DIR=r'genres_train_val_split_data/train'
val_dir = r'genres_train_val_split_data/val'

# data prep
train_datagen = ImageDataGenerator(
    rescale=1./255.,validation_split=0.25)


train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(HEIGHT, WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical')

validation_gen = train_datagen.flow_from_directory(
    val_dir,target_size = (HEIGHT,WIDTH),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical'
 )
# Out:
# Found 800 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %% [markdown]
# # Model Architecture

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=(64,64,3)))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.compile(optimizers.RMSprop(learning_rate=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 62, 62, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 31, 31, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 29, 29, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 29, 29, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 12, 12, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,679,626 (10.22 MB)
#  Trainable params: 2,679,626 (10.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# Measure the execution time
start_time = time.time()

model.fit(train_generator,validation_data=validation_gen,epochs=200)

end_time = time.time()
elapsed_time = end_time - start_time
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 538ms/step - accuracy: 0.1011 - loss: 2.3242 - val_accuracy: 0.1150 - val_loss: 2.2923
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 570ms/step - accuracy: 0.1581 - loss: 2.2669 - val_accuracy: 0.2550 - val_loss: 2.1166
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 518ms/step - accuracy: 0.2058 - loss: 2.0895 - val_accuracy: 0.2450 - val_loss: 2.0357
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 551ms/step - accuracy: 0.2426 - loss: 2.0326 - val_accuracy: 0.2750 - val_loss: 1.9764
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 517ms/step - accuracy: 0.2303 - loss: 1.9987 - val_accuracy: 0.3150 - val_loss: 1.9558
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 533ms/step - accuracy: 0.2637 - loss: 2.0296 - val_accuracy: 0.2850 - val_loss: 1.9006
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 533ms/step - accuracy: 0.2771 - loss: 1.9910 - val_accuracy: 0.2850 - val_loss: 1.8707
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 522ms/step - accuracy: 0.3095 - loss: 1.9647 - val_accuracy: 0.3100 - val_loss: 1.9036
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 571ms/step - accuracy: 0.3429 - loss: 1.9194 - val_accuracy: 0.3550 - val_loss: 1.7404
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 575ms/step - accuracy: 0.3321 - loss: 1.8754 - val_accuracy: 0.4250 - val_loss: 1.6389
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 522ms/step - accuracy: 0.3783 - loss: 1.7874 - val_accuracy: 0.4050 - val_loss: 1.5731
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 567ms/step - accuracy: 0.4319 - loss: 1.6884 - val_accuracy: 0.4200 - val_loss: 1.5940
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 543ms/step - accuracy: 0.3962 - loss: 1.6742 - val_accuracy: 0.3900 - val_loss: 1.5297
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 567ms/step - accuracy: 0.4067 - loss: 1.6049 - val_accuracy: 0.4500 - val_loss: 1.5698
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 566ms/step - accuracy: 0.4456 - loss: 1.5497 - val_accuracy: 0.4650 - val_loss: 1.4756
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 569ms/step - accuracy: 0.4469 - loss: 1.5176 - val_accuracy: 0.4700 - val_loss: 1.4376
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 589ms/step - accuracy: 0.4596 - loss: 1.5198 - val_accuracy: 0.4700 - val_loss: 1.4493
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 534ms/step - accuracy: 0.4696 - loss: 1.4725 - val_accuracy: 0.4600 - val_loss: 1.3973
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 569ms/step - accuracy: 0.4480 - loss: 1.4829 - val_accuracy: 0.5250 - val_loss: 1.3373
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 556ms/step - accuracy: 0.4856 - loss: 1.4397 - val_accuracy: 0.5100 - val_loss: 1.3024
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 552ms/step - accuracy: 0.4826 - loss: 1.3483 - val_accuracy: 0.5150 - val_loss: 1.3318
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 539ms/step - accuracy: 0.5327 - loss: 1.3442 - val_accuracy: 0.5500 - val_loss: 1.3132
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 527ms/step - accuracy: 0.5250 - loss: 1.2634 - val_accuracy: 0.4900 - val_loss: 1.2718
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 529ms/step - accuracy: 0.5511 - loss: 1.2382 - val_accuracy: 0.5350 - val_loss: 1.2388
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 525ms/step - accuracy: 0.5507 - loss: 1.2696 - val_accuracy: 0.5550 - val_loss: 1.2055
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.5724 - loss: 1.1886 - val_accuracy: 0.6000 - val_loss: 1.1176
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 555ms/step - accuracy: 0.5658 - loss: 1.2289 - val_accuracy: 0.5200 - val_loss: 1.2037
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 542ms/step - accuracy: 0.5507 - loss: 1.2042 - val_accuracy: 0.5250 - val_loss: 1.2184
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 543ms/step - accuracy: 0.6093 - loss: 1.1334 - val_accuracy: 0.5550 - val_loss: 1.1755
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 539ms/step - accuracy: 0.6209 - loss: 1.1099 - val_accuracy: 0.5550 - val_loss: 1.2924
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 512ms/step - accuracy: 0.5809 - loss: 1.1210 - val_accuracy: 0.5450 - val_loss: 1.1799
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 565ms/step - accuracy: 0.6495 - loss: 1.0060 - val_accuracy: 0.5050 - val_loss: 1.2574
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 564ms/step - accuracy: 0.6314 - loss: 1.0509 - val_accuracy: 0.5950 - val_loss: 1.0952
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 571ms/step - accuracy: 0.6474 - loss: 0.9586 - val_accuracy: 0.5750 - val_loss: 1.0542
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.6378 - loss: 0.9995 - val_accuracy: 0.5450 - val_loss: 1.3593
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 551ms/step - accuracy: 0.6409 - loss: 0.9626 - val_accuracy: 0.5950 - val_loss: 1.0638
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 552ms/step - accuracy: 0.6874 - loss: 0.8909 - val_accuracy: 0.6000 - val_loss: 1.0796
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 504ms/step - accuracy: 0.6863 - loss: 0.8537 - val_accuracy: 0.5650 - val_loss: 1.1675
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 546ms/step - accuracy: 0.6875 - loss: 0.8593 - val_accuracy: 0.5700 - val_loss: 1.3271
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 553ms/step - accuracy: 0.6566 - loss: 0.8575 - val_accuracy: 0.5400 - val_loss: 1.4531
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 562ms/step - accuracy: 0.7167 - loss: 0.7923 - val_accuracy: 0.5800 - val_loss: 1.1807
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 540ms/step - accuracy: 0.7343 - loss: 0.7148 - val_accuracy: 0.4650 - val_loss: 1.5784
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.7109 - loss: 0.9480 - val_accuracy: 0.5600 - val_loss: 1.2064
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 543ms/step - accuracy: 0.7607 - loss: 0.6781 - val_accuracy: 0.6050 - val_loss: 1.1919
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 522ms/step - accuracy: 0.7433 - loss: 0.6988 - val_accuracy: 0.5900 - val_loss: 1.2368
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 524ms/step - accuracy: 0.7835 - loss: 0.5573 - val_accuracy: 0.5800 - val_loss: 1.1916
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 531ms/step - accuracy: 0.7888 - loss: 0.6054 - val_accuracy: 0.6150 - val_loss: 1.2647
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 540ms/step - accuracy: 0.7698 - loss: 0.6031 - val_accuracy: 0.5450 - val_loss: 1.5276
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 564ms/step - accuracy: 0.8139 - loss: 0.5399 - val_accuracy: 0.6000 - val_loss: 1.1950
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 566ms/step - accuracy: 0.8152 - loss: 0.5775 - val_accuracy: 0.6000 - val_loss: 1.2047
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 577ms/step - accuracy: 0.8268 - loss: 0.5181 - val_accuracy: 0.6050 - val_loss: 1.2962
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 528ms/step - accuracy: 0.8375 - loss: 0.4889 - val_accuracy: 0.6200 - val_loss: 1.2497
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 567ms/step - accuracy: 0.8384 - loss: 0.4092 - val_accuracy: 0.5800 - val_loss: 1.6821
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 546ms/step - accuracy: 0.8177 - loss: 0.5194 - val_accuracy: 0.6150 - val_loss: 1.1508
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 0.8295 - loss: 0.4409 - val_accuracy: 0.5250 - val_loss: 2.3402
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 547ms/step - accuracy: 0.8378 - loss: 0.5271 - val_accuracy: 0.6100 - val_loss: 1.3929
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 573ms/step - accuracy: 0.8603 - loss: 0.3833 - val_accuracy: 0.6450 - val_loss: 1.3429
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 515ms/step - accuracy: 0.8618 - loss: 0.4340 - val_accuracy: 0.6200 - val_loss: 1.4654
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 538ms/step - accuracy: 0.8659 - loss: 0.3863 - val_accuracy: 0.5950 - val_loss: 1.5425
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 537ms/step - accuracy: 0.8430 - loss: 0.3965 - val_accuracy: 0.5650 - val_loss: 1.6565
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.8477 - loss: 0.3745 - val_accuracy: 0.5900 - val_loss: 1.4345
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 532ms/step - accuracy: 0.8870 - loss: 0.3287 - val_accuracy: 0.6200 - val_loss: 1.6038
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 543ms/step - accuracy: 0.9076 - loss: 0.2745 - val_accuracy: 0.5900 - val_loss: 1.5555
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 530ms/step - accuracy: 0.9116 - loss: 0.3056 - val_accuracy: 0.6000 - val_loss: 1.6835
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 505ms/step - accuracy: 0.9101 - loss: 0.2869 - val_accuracy: 0.6300 - val_loss: 1.7449
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 524ms/step - accuracy: 0.8984 - loss: 0.2971 - val_accuracy: 0.5600 - val_loss: 1.7983
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 565ms/step - accuracy: 0.8988 - loss: 0.3030 - val_accuracy: 0.5850 - val_loss: 1.6539
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 577ms/step - accuracy: 0.9022 - loss: 0.3070 - val_accuracy: 0.6450 - val_loss: 1.6759
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 558ms/step - accuracy: 0.9082 - loss: 0.2517 - val_accuracy: 0.6350 - val_loss: 1.5519
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 577ms/step - accuracy: 0.9072 - loss: 0.2899 - val_accuracy: 0.5850 - val_loss: 1.6215
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9161 - loss: 0.2385 - val_accuracy: 0.6050 - val_loss: 1.6027
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 526ms/step - accuracy: 0.9248 - loss: 0.2151 - val_accuracy: 0.5850 - val_loss: 1.8463
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 533ms/step - accuracy: 0.9297 - loss: 0.2140 - val_accuracy: 0.6350 - val_loss: 1.5837
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 559ms/step - accuracy: 0.9258 - loss: 0.2115 - val_accuracy: 0.6400 - val_loss: 1.4993
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 569ms/step - accuracy: 0.9472 - loss: 0.1653 - val_accuracy: 0.5900 - val_loss: 2.0353
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 536ms/step - accuracy: 0.9459 - loss: 0.1702 - val_accuracy: 0.5650 - val_loss: 1.8155
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 542ms/step - accuracy: 0.9427 - loss: 0.1755 - val_accuracy: 0.5750 - val_loss: 2.0428
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 540ms/step - accuracy: 0.9189 - loss: 0.2079 - val_accuracy: 0.6050 - val_loss: 1.7019
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 533ms/step - accuracy: 0.9453 - loss: 0.1635 - val_accuracy: 0.6200 - val_loss: 2.0832
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 574ms/step - accuracy: 0.9276 - loss: 0.2024 - val_accuracy: 0.6000 - val_loss: 2.1653
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 573ms/step - accuracy: 0.9348 - loss: 0.1973 - val_accuracy: 0.5950 - val_loss: 2.1422
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.9503 - loss: 0.1624 - val_accuracy: 0.5850 - val_loss: 2.0407
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.9391 - loss: 0.1776 - val_accuracy: 0.5800 - val_loss: 2.1591
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9488 - loss: 0.1554 - val_accuracy: 0.6150 - val_loss: 2.1209
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 561ms/step - accuracy: 0.9244 - loss: 0.2635 - val_accuracy: 0.5950 - val_loss: 1.9905
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 562ms/step - accuracy: 0.9521 - loss: 0.1275 - val_accuracy: 0.5850 - val_loss: 2.1589
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 552ms/step - accuracy: 0.9430 - loss: 0.1691 - val_accuracy: 0.6150 - val_loss: 2.2202
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 558ms/step - accuracy: 0.9453 - loss: 0.1922 - val_accuracy: 0.6000 - val_loss: 1.8852
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 575ms/step - accuracy: 0.9563 - loss: 0.1267 - val_accuracy: 0.5850 - val_loss: 2.0853
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9615 - loss: 0.1172 - val_accuracy: 0.6050 - val_loss: 2.0372
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 541ms/step - accuracy: 0.9572 - loss: 0.1315 - val_accuracy: 0.6300 - val_loss: 1.9212
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 512ms/step - accuracy: 0.9555 - loss: 0.1318 - val_accuracy: 0.6400 - val_loss: 1.7290
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9569 - loss: 0.1059 - val_accuracy: 0.6100 - val_loss: 2.0061
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 545ms/step - accuracy: 0.9716 - loss: 0.1004 - val_accuracy: 0.6050 - val_loss: 2.0350
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 538ms/step - accuracy: 0.9702 - loss: 0.0816 - val_accuracy: 0.5950 - val_loss: 2.0674
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 525ms/step - accuracy: 0.9676 - loss: 0.1146 - val_accuracy: 0.6000 - val_loss: 1.9159
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 559ms/step - accuracy: 0.9797 - loss: 0.0727 - val_accuracy: 0.6550 - val_loss: 2.0759
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 521ms/step - accuracy: 0.9502 - loss: 0.1253 - val_accuracy: 0.6250 - val_loss: 1.8683
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 531ms/step - accuracy: 0.9535 - loss: 0.1650 - val_accuracy: 0.6500 - val_loss: 2.2997
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 546ms/step - accuracy: 0.9678 - loss: 0.1006 - val_accuracy: 0.6050 - val_loss: 2.2484
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 580ms/step - accuracy: 0.9664 - loss: 0.1002 - val_accuracy: 0.6000 - val_loss: 2.2426
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 548ms/step - accuracy: 0.9566 - loss: 0.1877 - val_accuracy: 0.6300 - val_loss: 2.3381
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 591ms/step - accuracy: 0.9609 - loss: 0.0924 - val_accuracy: 0.6200 - val_loss: 2.6084
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 555ms/step - accuracy: 0.9650 - loss: 0.1057 - val_accuracy: 0.6350 - val_loss: 2.2494
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 561ms/step - accuracy: 0.9372 - loss: 0.2152 - val_accuracy: 0.6350 - val_loss: 2.3142
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 527ms/step - accuracy: 0.9733 - loss: 0.0733 - val_accuracy: 0.6050 - val_loss: 2.3158
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 519ms/step - accuracy: 0.9712 - loss: 0.0965 - val_accuracy: 0.6300 - val_loss: 2.0445
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 583ms/step - accuracy: 0.9696 - loss: 0.1037 - val_accuracy: 0.5200 - val_loss: 3.7055
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 541ms/step - accuracy: 0.9442 - loss: 0.2442 - val_accuracy: 0.6250 - val_loss: 2.2329
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 531ms/step - accuracy: 0.9718 - loss: 0.0890 - val_accuracy: 0.6300 - val_loss: 2.1033
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 520ms/step - accuracy: 0.9691 - loss: 0.0714 - val_accuracy: 0.5650 - val_loss: 2.9281
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9548 - loss: 0.1614 - val_accuracy: 0.6600 - val_loss: 2.2891
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 504ms/step - accuracy: 0.9884 - loss: 0.0329 - val_accuracy: 0.5550 - val_loss: 3.6201
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 564ms/step - accuracy: 0.9516 - loss: 0.2115 - val_accuracy: 0.6350 - val_loss: 2.3607
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 566ms/step - accuracy: 0.9858 - loss: 0.0397 - val_accuracy: 0.6300 - val_loss: 2.4544
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 577ms/step - accuracy: 0.9693 - loss: 0.1138 - val_accuracy: 0.5950 - val_loss: 2.5140
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 529ms/step - accuracy: 0.9765 - loss: 0.0637 - val_accuracy: 0.5850 - val_loss: 2.7101
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 558ms/step - accuracy: 0.9723 - loss: 0.0785 - val_accuracy: 0.5750 - val_loss: 2.7907
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 537ms/step - accuracy: 0.9748 - loss: 0.0702 - val_accuracy: 0.5600 - val_loss: 2.3540
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 564ms/step - accuracy: 0.9717 - loss: 0.1028 - val_accuracy: 0.5900 - val_loss: 2.8315
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 588ms/step - accuracy: 0.9813 - loss: 0.0669 - val_accuracy: 0.6050 - val_loss: 2.3520
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 555ms/step - accuracy: 0.9931 - loss: 0.0362 - val_accuracy: 0.6050 - val_loss: 2.8955
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 533ms/step - accuracy: 0.9805 - loss: 0.1227 - val_accuracy: 0.6250 - val_loss: 2.5839
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 574ms/step - accuracy: 0.9742 - loss: 0.0694 - val_accuracy: 0.5750 - val_loss: 3.0365
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 543ms/step - accuracy: 0.9684 - loss: 0.1656 - val_accuracy: 0.6050 - val_loss: 2.3917
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 503ms/step - accuracy: 0.9788 - loss: 0.0757 - val_accuracy: 0.6400 - val_loss: 2.4538
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 557ms/step - accuracy: 0.9693 - loss: 0.1052 - val_accuracy: 0.6200 - val_loss: 2.7530
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 0.9728 - loss: 0.0862 - val_accuracy: 0.6350 - val_loss: 2.4695
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 531ms/step - accuracy: 0.9755 - loss: 0.0719 - val_accuracy: 0.6550 - val_loss: 2.5445
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 564ms/step - accuracy: 0.9726 - loss: 0.0904 - val_accuracy: 0.6150 - val_loss: 2.6390
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 552ms/step - accuracy: 0.9788 - loss: 0.0723 - val_accuracy: 0.6100 - val_loss: 2.8174
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 553ms/step - accuracy: 0.9741 - loss: 0.1616 - val_accuracy: 0.5800 - val_loss: 3.3298
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 524ms/step - accuracy: 0.9742 - loss: 0.0859 - val_accuracy: 0.6050 - val_loss: 2.8414
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 563ms/step - accuracy: 0.9688 - loss: 0.0752 - val_accuracy: 0.6300 - val_loss: 2.6067
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 561ms/step - accuracy: 0.9828 - loss: 0.0470 - val_accuracy: 0.6150 - val_loss: 2.5203
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 568ms/step - accuracy: 0.9812 - loss: 0.0563 - val_accuracy: 0.6250 - val_loss: 2.6970
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 591ms/step - accuracy: 0.9744 - loss: 0.0902 - val_accuracy: 0.6000 - val_loss: 2.8552
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 551ms/step - accuracy: 0.9727 - loss: 0.0856 - val_accuracy: 0.6350 - val_loss: 2.6460
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9888 - loss: 0.0262 - val_accuracy: 0.6200 - val_loss: 3.0556
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 539ms/step - accuracy: 0.9698 - loss: 0.1233 - val_accuracy: 0.6250 - val_loss: 2.6586
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 586ms/step - accuracy: 0.9867 - loss: 0.0366 - val_accuracy: 0.5550 - val_loss: 2.6402
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 544ms/step - accuracy: 0.9756 - loss: 0.1121 - val_accuracy: 0.5800 - val_loss: 2.9416
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.9759 - loss: 0.0806 - val_accuracy: 0.5850 - val_loss: 3.0496
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 563ms/step - accuracy: 0.9869 - loss: 0.0533 - val_accuracy: 0.6450 - val_loss: 2.8478
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 567ms/step - accuracy: 0.9868 - loss: 0.0399 - val_accuracy: 0.6000 - val_loss: 2.8442
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 506ms/step - accuracy: 0.9908 - loss: 0.0471 - val_accuracy: 0.5950 - val_loss: 3.4269
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 540ms/step - accuracy: 0.9581 - loss: 0.1419 - val_accuracy: 0.6250 - val_loss: 2.7475
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 541ms/step - accuracy: 0.9831 - loss: 0.0400 - val_accuracy: 0.5600 - val_loss: 3.1828
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 559ms/step - accuracy: 0.9693 - loss: 0.1216 - val_accuracy: 0.6100 - val_loss: 2.6053
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 538ms/step - accuracy: 0.9855 - loss: 0.0509 - val_accuracy: 0.6350 - val_loss: 3.2490
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 546ms/step - accuracy: 0.9787 - loss: 0.0802 - val_accuracy: 0.6250 - val_loss: 3.0706
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 542ms/step - accuracy: 0.9680 - loss: 0.0994 - val_accuracy: 0.5850 - val_loss: 3.2184
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 539ms/step - accuracy: 0.9848 - loss: 0.0572 - val_accuracy: 0.6100 - val_loss: 3.2092
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 543ms/step - accuracy: 0.9878 - loss: 0.0451 - val_accuracy: 0.5750 - val_loss: 2.9277
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 562ms/step - accuracy: 0.9870 - loss: 0.0619 - val_accuracy: 0.6350 - val_loss: 2.8007
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 579ms/step - accuracy: 0.9828 - loss: 0.0757 - val_accuracy: 0.6600 - val_loss: 2.7538
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 562ms/step - accuracy: 0.9784 - loss: 0.0706 - val_accuracy: 0.6150 - val_loss: 2.9979
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.9825 - loss: 0.0501 - val_accuracy: 0.6050 - val_loss: 2.8109
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 568ms/step - accuracy: 0.9729 - loss: 0.0766 - val_accuracy: 0.5800 - val_loss: 2.9087
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 535ms/step - accuracy: 0.9847 - loss: 0.0489 - val_accuracy: 0.5600 - val_loss: 3.2906
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 534ms/step - accuracy: 0.9719 - loss: 0.0868 - val_accuracy: 0.6150 - val_loss: 2.8960
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 552ms/step - accuracy: 0.9950 - loss: 0.0201 - val_accuracy: 0.5850 - val_loss: 3.5152
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 554ms/step - accuracy: 0.9698 - loss: 0.0716 - val_accuracy: 0.5800 - val_loss: 2.9230
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 562ms/step - accuracy: 0.9926 - loss: 0.0250 - val_accuracy: 0.6650 - val_loss: 2.9517
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 565ms/step - accuracy: 0.9884 - loss: 0.0319 - val_accuracy: 0.6500 - val_loss: 3.0046
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 511ms/step - accuracy: 0.9829 - loss: 0.0537 - val_accuracy: 0.6000 - val_loss: 3.0556
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 594ms/step - accuracy: 0.9842 - loss: 0.0595 - val_accuracy: 0.5900 - val_loss: 3.2197
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 551ms/step - accuracy: 0.9515 - loss: 0.1508 - val_accuracy: 0.5950 - val_loss: 3.2109
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 545ms/step - accuracy: 0.9882 - loss: 0.0536 - val_accuracy: 0.5750 - val_loss: 3.9917
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 567ms/step - accuracy: 0.9813 - loss: 0.0697 - val_accuracy: 0.5950 - val_loss: 3.4645
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 0.9758 - loss: 0.1168 - val_accuracy: 0.6200 - val_loss: 2.9054
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 561ms/step - accuracy: 0.9791 - loss: 0.0757 - val_accuracy: 0.6100 - val_loss: 3.2197
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 530ms/step - accuracy: 0.9680 - loss: 0.1134 - val_accuracy: 0.5850 - val_loss: 3.3476
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 594ms/step - accuracy: 0.9911 - loss: 0.0345 - val_accuracy: 0.6150 - val_loss: 2.9289
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 580ms/step - accuracy: 0.9842 - loss: 0.0511 - val_accuracy: 0.5950 - val_loss: 3.4019
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 565ms/step - accuracy: 0.9777 - loss: 0.0822 - val_accuracy: 0.6250 - val_loss: 2.8452
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 0.9834 - loss: 0.0470 - val_accuracy: 0.5700 - val_loss: 3.1956
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 546ms/step - accuracy: 0.9544 - loss: 0.0933 - val_accuracy: 0.5950 - val_loss: 3.8561
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 537ms/step - accuracy: 0.9892 - loss: 0.0523 - val_accuracy: 0.6100 - val_loss: 3.8852
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 572ms/step - accuracy: 0.9847 - loss: 0.0463 - val_accuracy: 0.6000 - val_loss: 3.2958
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.9917 - loss: 0.0208 - val_accuracy: 0.6250 - val_loss: 2.9632
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 539ms/step - accuracy: 0.9789 - loss: 0.0541 - val_accuracy: 0.6350 - val_loss: 3.2442
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 538ms/step - accuracy: 0.9798 - loss: 0.0785 - val_accuracy: 0.6300 - val_loss: 3.5262
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 565ms/step - accuracy: 0.9856 - loss: 0.0394 - val_accuracy: 0.6450 - val_loss: 3.4917
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 540ms/step - accuracy: 0.9818 - loss: 0.0505 - val_accuracy: 0.6400 - val_loss: 3.2477
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 493ms/step - accuracy: 0.9845 - loss: 0.0379 - val_accuracy: 0.6100 - val_loss: 3.8613
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 577ms/step - accuracy: 0.9885 - loss: 0.0442 - val_accuracy: 0.6350 - val_loss: 3.2838
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.9867 - loss: 0.0585 - val_accuracy: 0.5950 - val_loss: 3.0047
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 554ms/step - accuracy: 0.9937 - loss: 0.0197 - val_accuracy: 0.6100 - val_loss: 3.1130
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 549ms/step - accuracy: 0.9843 - loss: 0.0295 - val_accuracy: 0.6200 - val_loss: 3.4915
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 563ms/step - accuracy: 0.9940 - loss: 0.0119 - val_accuracy: 0.5950 - val_loss: 4.3651
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 592ms/step - accuracy: 0.9849 - loss: 0.0648 - val_accuracy: 0.5850 - val_loss: 3.6716
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.9823 - loss: 0.0545 - val_accuracy: 0.5500 - val_loss: 3.8782
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 582ms/step - accuracy: 0.9938 - loss: 0.0356 - val_accuracy: 0.5300 - val_loss: 4.1385
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 545ms/step - accuracy: 0.9755 - loss: 0.0617 - val_accuracy: 0.6200 - val_loss: 3.0133
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.9814 - loss: 0.0416 - val_accuracy: 0.5950 - val_loss: 3.9971
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.9805 - loss: 0.0663 - val_accuracy: 0.5900 - val_loss: 4.2439
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 553ms/step - accuracy: 0.9689 - loss: 0.1635 - val_accuracy: 0.6100 - val_loss: 3.5457
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 544ms/step - accuracy: 0.9917 - loss: 0.0255 - val_accuracy: 0.6450 - val_loss: 3.7831
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 512ms/step - accuracy: 0.9820 - loss: 0.0697 - val_accuracy: 0.5750 - val_loss: 4.4425

# %%
print(f"Execution time: {elapsed_time:.2f} seconds")
# Out:
# Execution time: 2750.56 seconds
