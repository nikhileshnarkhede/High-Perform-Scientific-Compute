# %% [markdown]
# # Import Lib

# %%
import os
from glob import glob
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import ipyparallel as ipp
import time
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # Function to create a spectrogram from an audio file

# %%
def create_spectrogram(filename, name, store_path):
    plt.interactive(False)
    clip, sample_rate = librosa.load(filename, sr=None)
    fig = plt.figure(figsize=[0.72, 0.72])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y=clip, sr=sample_rate)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    filename = os.path.join(store_path, name + '.jpg')
    plt.savefig(filename, dpi=400, bbox_inches='tight', pad_inches=0)
    plt.close()
    fig.clf()
    plt.close(fig)
    plt.close('all')
    del filename, name, clip, sample_rate, fig, ax, S

# %% [markdown]
# # Helper function to process a single audio file

# %%
def process_audio_file(file, folder_path):
    name = os.path.basename(file)
    create_spectrogram(file, name, folder_path)

# %% [markdown]
# # Convert Audio files to spectrogram JPG files with ipyparallel

# %%
def Convert_Audio_File_to_jpg_file(filename, number_of_worker):
    """
    Convert audio files to spectrogram JPG files using ipyparallel.

    Parameters:
        filename (str): Path to the main directory containing audio files and number of worker.
    """
    # Set up ipyparallel cluster
    Execution_time = 0
    rc = ipp.Cluster(n=number_of_worker).start_and_connect_sync()  # Start and connect cluster with 4 workers
    dview = rc[:]  # Create a direct view to all workers

    dview.push({"create_spectrogram": create_spectrogram})
    dview.push({"process_audio_file": process_audio_file})
    dview.execute("import os")
    dview.execute("import librosa")
    dview.execute("import librosa.display")
    dview.execute("import numpy as np")
    dview.execute("import matplotlib.pyplot as plt")
    dview.execute("import time")

    start_time = time.time()
    # Make a dictionary for given class and their file path names
    file_list = glob(os.path.join(filename, "*"))
    file_dic = {}
    for file in file_list:
        all_files = []
        for root, dirs, files in os.walk(file):
            for file_ in files:
                # Join the root directory with the file name to get the full path
                all_files.append(os.path.join(root, file_))
        file_dic[file] = all_files

    # Create file directories to store the converted audio files into JPG
    file_path = []
    for folder in file_dic.keys():
        folder_rot = os.path.join('Convert_Audio_File_to_jpg_file', os.path.basename(folder))
        file_path.append(folder_rot)
        os.makedirs(folder_rot, exist_ok=True)

    # Delegate work to workers using dview.map_sync()
    for i, folder in enumerate(file_dic.keys()):
        music_files = file_dic[folder]
        folder_path = file_path[i]
        # Map the processing function across music files with ipyparallel
        dview.map_sync(lambda file: process_audio_file(file, folder_path), music_files)
    end_time = time.time()
    elapsed_time = end_time - start_time
    Execution_time = elapsed_time
    print(f"Execution time: {elapsed_time:.2f} seconds")
    # Shut down the cluster after processing
    rc.shutdown()

    return Execution_time

# %% [markdown]
# # Convert Audio File to jpg file

# %%
Convert_Audio_File_to_jpg_file("genres",number_of_worker = 4)
# Out:
# Starting 4 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/4 [00:00<?, ?engine/s]
# Execution time: 38.11 seconds
# 38.10851836204529
# engine set stopped 1733362975: {'engines': {'0': {'exit_code': 0, 'pid': 19320, 'identifier': '0'}, '2': {'exit_code': 0, 'pid': 14060, 'identifier': '2'}, '3': {'exit_code': 0, 'pid': 19056, 'identifier': '3'}, '1': {'exit_code': 0, 'pid': 2248, 'identifier': '1'}}, 'exit_code': 0}

# %% [markdown]
# # Experiment with Core

# %%
Execution_time = []
Cores = range(1,9)
for number_of_worker in Cores:
   Execution_time.append(Convert_Audio_File_to_jpg_file("genres",number_of_worker = number_of_worker))
# Out:
# Starting 1 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/1 [00:00<?, ?engine/s]
# Execution time: 156.24 seconds
# Failed to remove C:\Users\nikhi\.ipython\profile_default\log\ipengine-1733363019-2ft2-1733363020-0.log: [WinError 5] Access is denied: 'C:\\Users\\nikhi\\.ipython\\profile_default\\log\\ipengine-1733363019-2ft2-1733363020-0.log'
# engine set stopped 1733363020: {'engines': {'0': {'exit_code': 0, 'pid': 10536, 'identifier': '0'}}, 'exit_code': 0}
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/2 [00:00<?, ?engine/s]
# Execution time: 70.85 seconds
# engine set stopped 1733363184: {'engines': {'1': {'exit_code': 0, 'pid': 18080, 'identifier': '1'}, '0': {'exit_code': 0, 'pid': 19288, 'identifier': '0'}}, 'exit_code': 0}
# Starting 3 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/3 [00:00<?, ?engine/s]
# Execution time: 53.73 seconds
# engine set stopped 1733363263: {'engines': {'2': {'exit_code': 0, 'pid': 16748, 'identifier': '2'}, '1': {'exit_code': 0, 'pid': 19132, 'identifier': '1'}, '0': {'exit_code': 0, 'pid': 13368, 'identifier': '0'}}, 'exit_code': 0}
# Starting 4 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/4 [00:00<?, ?engine/s]
# Execution time: 42.69 seconds
# Failed to remove C:\Users\nikhi\.ipython\profile_default\log\ipengine-1733363323-8x97-1733363324-1.log: [WinError 2] The system cannot find the file specified: 'C:\\Users\\nikhi\\.ipython\\profile_default\\log\\ipengine-1733363323-8x97-1733363324-1.log'
# Failed to remove C:\Users\nikhi\.ipython\profile_default\log\ipengine-1733363323-8x97-1733363324-2.log: [WinError 2] The system cannot find the file specified: 'C:\\Users\\nikhi\\.ipython\\profile_default\\log\\ipengine-1733363323-8x97-1733363324-2.log'
# engine set stopped 1733363324: {'engines': {'3': {'exit_code': 0, 'pid': 14232, 'identifier': '3'}, '0': {'exit_code': 0, 'pid': 19876, 'identifier': '0'}, '1': {'exit_code': 0, 'pid': 17844, 'identifier': '1'}, '2': {'exit_code': 0, 'pid': 9544, 'identifier': '2'}}, 'exit_code': 0}
# Starting 5 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/5 [00:00<?, ?engine/s]
# Execution time: 35.00 seconds
# engine set stopped 1733363374: {'engines': {'0': {'exit_code': 0, 'pid': 12028, 'identifier': '0'}, '2': {'exit_code': 0, 'pid': 2580, 'identifier': '2'}, '1': {'exit_code': 0, 'pid': 600, 'identifier': '1'}, '3': {'exit_code': 0, 'pid': 13200, 'identifier': '3'}, '4': {'exit_code': 0, 'pid': 7392, 'identifier': '4'}}, 'exit_code': 0}
# Starting 6 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/6 [00:00<?, ?engine/s]
# Execution time: 30.99 seconds
# engine set stopped 1733363417: {'engines': {'2': {'exit_code': 0, 'pid': 9796, 'identifier': '2'}, '5': {'exit_code': 0, 'pid': 12460, 'identifier': '5'}, '0': {'exit_code': 0, 'pid': 2356, 'identifier': '0'}, '1': {'exit_code': 0, 'pid': 4868, 'identifier': '1'}, '3': {'exit_code': 0, 'pid': 22092, 'identifier': '3'}, '4': {'exit_code': 0, 'pid': 18400, 'identifier': '4'}}, 'exit_code': 0}
# Starting 7 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/7 [00:00<?, ?engine/s]
# Execution time: 28.01 seconds
# Failed to remove C:\Users\nikhi\.ipython\profile_default\log\ipengine-1733363454-g0bh-1733363455-2.log: [WinError 2] The system cannot find the file specified: 'C:\\Users\\nikhi\\.ipython\\profile_default\\log\\ipengine-1733363454-g0bh-1733363455-2.log'
# engine set stopped 1733363455: {'engines': {'2': {'exit_code': 0, 'pid': 19884, 'identifier': '2'}, '6': {'exit_code': 0, 'pid': 13236, 'identifier': '6'}, '0': {'exit_code': 0, 'pid': 10108, 'identifier': '0'}, '4': {'exit_code': 0, 'pid': 18816, 'identifier': '4'}, '3': {'exit_code': 0, 'pid': 11592, 'identifier': '3'}, '5': {'exit_code': 0, 'pid': 1476, 'identifier': '5'}, '1': {'exit_code': 0, 'pid': 22336, 'identifier': '1'}}, 'exit_code': 0}
# Starting 8 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/8 [00:00<?, ?engine/s]
# Execution time: 25.88 seconds
# engine set stopped 1733363491: {'engines': {'5': {'exit_code': 0, 'pid': 5988, 'identifier': '5'}, '0': {'exit_code': 0, 'pid': 22540, 'identifier': '0'}, '6': {'exit_code': 0, 'pid': 9748, 'identifier': '6'}, '7': {'exit_code': 0, 'pid': 18436, 'identifier': '7'}, '3': {'exit_code': 0, 'pid': 17376, 'identifier': '3'}, '2': {'exit_code': 0, 'pid': 22712, 'identifier': '2'}, '1': {'exit_code': 0, 'pid': 22628, 'identifier': '1'}, '4': {'exit_code': 0, 'pid': 21492, 'identifier': '4'}}, 'exit_code': 0}

# %% [markdown]
# ## Number of Core vs Execution time

# %%
plt.plot(Cores, Execution_time)
plt.xlabel('Number of Core')
plt.ylabel('Execution time')
plt.title('Number of Core vs Execution time')
plt.show()

# %% [markdown]
# ## Number of Core vs Speed Up

# %%
speed_up = []
for i in Cores:
    speed_up.append(Execution_time[0] / Execution_time[i - 1])

plt.plot(Cores, speed_up)
plt.xlabel('Number of Core')
plt.ylabel('Speed Up')
plt.title('Number of Core vs Speed Up')
plt.show()

# %% [markdown]
# ## Number of Core vs Efficiency

# %%
Efficiency = []
for num_of_core in Cores:
    Efficiency.append(speed_up[num_of_core - 1] / num_of_core)
    
plt.plot(Cores, Efficiency)
plt.xlabel('Number of Core')
plt.ylabel('Efficiency ')
plt.title('Number of Core vs Efficiency')
plt.show()
